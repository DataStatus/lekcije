# %% [markdown]
# #### ЛИНИЈСКИ ГРАФИКОН
# Надоградите програм тако да извршите додатна подешавања линијског графикона:
# Поставите зелену боју за линију графикона.
# Поставите ширину графикона на 16 а висину на 5, како би се видели називи производа.

# %%
proizvodi=["ratluk","medeno srce","jafa","plazma","wellness","barni","negro","gumene bombone","orbit","karamela"] 
ugljeni_hidrati=[84,66.1,69,70,56.9,58,95.5,45,58,78.8]

# %%
import matplotlib.pyplot as plt
plt.plot(proizvodi, ugljeni_hidrati)
plt.title("Količina ugljenih hidrata na 100g proizvoda")
plt.xlabel("Proizvodi")
plt.ylabel("Proteini")
plt.show()
plt.close()

# %% [markdown]
# #### СТУБИЧАСТИ ГРАФИКОН
# Надоградите програм тако да извршите додатна подешавања стубичастог графикона:
# Поставите жуту боју за ступце графикона.
# Поставите ширину графикона на 16 а висину на 5, како би се видели називи производа.

# %%
plt.bar(proizvodi, ugljeni_hidrati)
plt.title("Količina ugljenih hidrata na 100g proizvoda")
plt.xlabel("Proizvodi")
plt.ylabel("Proteini")
plt.show()
plt.close()

# %% [markdown]
# #### ТРИ СЕРИЈЕ ПОДАТАКА НА ИСТОМ ГРАФИКОНУ
# Надоградите програм тако да прикажете на истом стубичастом графикону угљене хидрате, протеине и масти за одређен производ. Уградите легенду у графикон.
# У ћелији испод дате су вам и вредности за две нове листе: proteini и masti.

# %%
proteini=[2.8,5.7,4.1,11.9,8.4,6,1,6.3,0,2.4]
masti=[0.3,8.5,9,12,23.7,16,1,0.5,0,12.9]
plt.bar(proizvodi, ugljeni_hidrati)
plt.title("Količina ugljenih hidrata na 100g proizvoda")
plt.xlabel("Proizvodi")
plt.ylabel("Proteini")
plt.show()
plt.close()

# %% [markdown]
# #### СЕКТОРСКИ ГРАФИКОН
# Надоградите програм тако да извршите додатна подешавања секторског графикона:
# Поставите ширину графикона на 8 а висину на 8, како би се видели називи производа.

# %%
plt.pie(ugljeni_hidrati, labels=proizvodi)
plt.title("Količina ugljenih hidrata na 1000g različitih proizvoda")
plt.show()
plt.close()
